# %% [markdown]
# 1D in numpy called as vector.
# 2D in numpy called as matrix.
#
#
# 1D in pandas called as Series.
# 2D in pandas called as DataFrame.

# %%
import pandas as pd

# %%
#Series
S1=pd.Series(data=[10,20,304,50],index=["Maths","eng","hindi","history"])
S2=pd.Series(data=[90,30,87,60],index=["Maths","eng","hindi","history"])
print(S1)
print(S2)
# Out:
# Maths       10
# eng         20
# hindi      304
# history     50
# dtype: int64
# Maths      90
# eng        30
# hindi      87
# history    60
# dtype: int64

# %%
S1["Maths"]
# Out:
# 10

# %%
S1.shape
# Out:
# (4,)

# %%
S1.size
# Out:
# 4

# %%
S1.dtypes
# Out:
# dtype('int64')

# %%
#DataFrame

Df1=pd.DataFrame(data={"Section1":[10,20,30,405],"Section2":[58,98,33,211]},index=[100,200,300,400])
print(Df1)
# Out:
#      Section1  Section2
# 100        10        58
# 200        20        98
# 300        30        33
# 400       405       211

# %%
Df2=pd.DataFrame(data={"Section1":S1,"Section2":S2})
Df2
# Out:
#          Section1  Section2
# Maths          10        90
# eng            20        30
# hindi         304        87
# history        50        60

# %% [markdown]
# # EDA(Exploratory Data Analysis)
# Also called as Data Wraggling
#
#
# Raw-> Data Exploration -> Data Cleaning  -> Data Preprocessing  -> Analysis  -> Machine Learning Model

# %%
#import the data set

df1=pd.read_csv("/Users/mythi/Downloads/loan_data_set.csv",sep=",") #for separation ,or ]..etc
df1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#how to create any feature as the index of the dataset.

pd.read_csv("/Users/mythi/Downloads/loan_data_set.csv",index_col=["Loan_ID"])  #index helps to identify colunms
# Out:
#           Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002    Male      No          0      Graduate            No
# LP001003    Male     Yes          1      Graduate            No
# LP001005    Male     Yes          0      Graduate           Yes
# LP001006    Male     Yes          0  Not Graduate            No
# LP001008    Male      No          0      Graduate            No
# ...          ...     ...        ...           ...           ...
# LP002978  Female      No          0      Graduate            No
# LP002979    Male     Yes         3+      Graduate            No
# LP002983    Male     Yes          1      Graduate            No
# LP002984    Male     Yes          2      Graduate            No
# LP002990  Female      No          0      Graduate           Yes
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0         NaN             360.0
# ...

# %%
#how to extract some set of rows and columns.
pd.read_csv("/Users/mythi/Downloads/loan_data_set.csv",usecols=["Married","Education","Self_Employed"],nrows=27)
# Out:
#    Married     Education Self_Employed
# 0       No      Graduate            No
# 1      Yes      Graduate            No
# 2      Yes      Graduate           Yes
# 3      Yes  Not Graduate            No
# 4       No      Graduate            No
# 5      Yes      Graduate           Yes
# 6      Yes  Not Graduate            No
# 7      Yes      Graduate            No
# 8      Yes      Graduate            No
# 9      Yes      Graduate            No
# 10     Yes      Graduate            No
# 11     Yes      Graduate           NaN
# 12     Yes      Graduate            No
# 13      No      Graduate            No
# 14     Yes      Graduate            No
# 15      No      Graduate            No
# 16      No  Not Graduate            No
# 17      No      Graduate            No
# 18     Yes  Not Graduate            No
# 19     Yes      Graduate           NaN
# 20     Yes  Not Graduate            No
# 21     Yes      Graduate            No
# 22     Yes  Not Graduate            No
# ...

# %%
#copy of data
df2=df1.copy()
df2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# # Data Exploration:
#
#  It is high level understanding and low level understanding.
#
#  # High Level understanding of the data:

# %%
df1.head()  #first 5 entries
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df1.tail()  #last 5 entries
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
df1.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
df1.describe()  #numerical colunms
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df1.describe(include="object")
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP001002   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
#
#        Property_Area Loan_Status
# count            614         614
# unique             3           2
# top        Semiurban           Y
# freq             233         422

# %%
df1.describe(include="all")
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP001002   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
# mean         NaN    NaN     NaN        NaN       NaN           NaN
# std          NaN    NaN     NaN        NaN       NaN           NaN
# min          NaN    NaN     NaN        NaN       NaN           NaN
# 25%          NaN    NaN     NaN        NaN       NaN           NaN
# 50%          NaN    NaN     NaN        NaN       NaN           NaN
# 75%          NaN    NaN     NaN        NaN       NaN           NaN
# max          NaN    NaN     NaN        NaN       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        614.000000         614.000000  592.000000         600.00000
# ...

# %% [markdown]
# # Low Level Understanding:
#
# 3 types:
#
# UniVariate:- Numerical type of data & Categorical data
# BiVariate:-
# MultiVariate:-

# %%
#univariate categorical type of data:

#how many customer got the loan?

df1["Loan_Status"].value_counts()                   #or df1.Loan_Status
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
#waht is the % of the customer who got the loan?
df1["Loan_Status"].value_counts(normalize=True)*100
# Out:
# Loan_Status
# Y    68.729642
# N    31.270358
# Name: proportion, dtype: float64

# %% [markdown]
# # Bar, Pie, Histogram, Line, Scatter, box plot, KDE(Kernel Density Estimated)

# %%
df1["Loan_Status"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
df1["Loan_Status"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
#univariate numerical of data.

df1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df1["ApplicantIncome"].describe()
# Out:
# count      614.000000
# mean      5403.459283
# std       6109.041673
# min        150.000000
# 25%       2877.500000
# 50%       3812.500000
# 75%       5795.000000
# max      81000.000000
# Name: ApplicantIncome, dtype: float64

# %%
df1["ApplicantIncome"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1["ApplicantIncome"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df1["LoanAmount"].plot(kind="box")
# Out:
# <Axes: >

# %%
dummy=pd.DataFrame(data={"col_1":[1,2,2,2,3,3,4,5,5,5,6,6,6,6,7,8,8,9,27]})
dummy
# Out:
#     col_1
# 0       1
# 1       2
# 2       2
# 3       2
# 4       3
# 5       3
# 6       4
# 7       5
# 8       5
# 9       5
# 10      6
# 11      6
# 12      6
# 13      6
# 14      7
# 15      8
# 16      8
# 17      9
# 18     27

# %%
dummy["col_1"].plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# #  Bivariate analysis:

# %%
df1.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
#how many female got the loan?

pd.crosstab(df1["Loan_Status"],df1["Gender"],margins=True)
# Out:
# Gender       Female  Male  All
# Loan_Status
# N                37   150  187
# Y                75   339  414
# All             112   489  601

# %%
pd.crosstab(df1["Loan_Status"],df1["Gender"],normalize="index")*100 #to calculate the %, we are using normalize #index means rows
# Out:
# Gender          Female       Male
# Loan_Status
# N            19.786096  80.213904
# Y            18.115942  81.884058

# %%
pd.crosstab(df1["Loan_Status"],df1["Gender"],normalize="columns")*100
# Out:
# Gender          Female       Male
# Loan_Status
# N            33.035714  30.674847
# Y            66.964286  69.325153

# %%
#bivariate numerical analysis:     #categorical featurre
x= df1.corr(method='pearson',min_periods=1)                  #corelation
x
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# Credit_History           -0.014715          -0.002056   -0.008433
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.045306       -0.014715
# CoapplicantIncome         -0.059878       -0.002056
# LoanAmount                 0.039447       -0.008433
# Loan_Amount_Term           1.000000        0.001470
# Credit_History             0.001470        1.000000

# %%
#heatmap

import seaborn as sns
sns.heatmap(x)
# Out:
# <Axes: >

# %%
help(df1.corr)
# Out:
# Help on method corr in module pandas.core.frame:
#
# corr(method: 'CorrelationMethod' = 'pearson', min_periods: 'int' = 1, numeric_only: 'bool' = False) -> 'DataFrame' method of pandas.core.frame.DataFrame instance
#     Compute pairwise correlation of columns, excluding NA/null values.
#
#     Parameters
#     ----------
#     method : {'pearson', 'kendall', 'spearman'} or callable
#         Method of correlation:
#
#         * pearson : standard correlation coefficient
#         * kendall : Kendall Tau correlation coefficient
#         * spearman : Spearman rank correlation
#         * callable: callable with input two 1d ndarrays
#             and returning a float. Note that the returned matrix from corr
#             will have 1 along the diagonals and will be symmetric
#             regardless of the callable's behavior.
#     min_periods : int, optional
#         Minimum number of observations required per pair of columns
# ...

# %%
df1.dtypes
# Out:
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# dtype: object

# %%
df1["new"]=df1["ApplicantIncome"]*83

# %%
df1
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History     new
# 0               1.0  485467
# 1               1.0  380389
# 2               1.0  249000
# ...

# %%
df1.corr()
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# Credit_History           -0.014715          -0.002056   -0.008433
# new                       1.000000          -0.116605    0.570909
#
#                    Loan_Amount_Term  Credit_History       new
# ApplicantIncome           -0.045306       -0.014715  1.000000
# CoapplicantIncome         -0.059878       -0.002056 -0.116605
# LoanAmount                 0.039447       -0.008433  0.570909
# Loan_Amount_Term           1.000000        0.001470 -0.045306
# Credit_History             0.001470        1.000000 -0.014715
# new                       -0.045306       -0.014715  1.000000

# %%
sns.heatmap(df1.corr(),cmap="Purples",annot=True)   #numerical feature
# Out:
# <Axes: >

# %%
del df1["new"]
df1
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History
# 0               1.0
# 1               1.0
# 2               1.0
# 3               1.0
# ...

# %%
#bivariate combination of numerical and categorical feature.

df1.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0

# %%
df1.boxplot(column="ApplicantIncome",by="Self_Employed")
# Out:
# <Axes: title={'center': 'ApplicantIncome'}, xlabel='Self_Employed'>

# %% [markdown]
# # Data Cleaning:

# %%
#finding the duplicates:

df1.duplicated().sum()
# Out:
# 0

# %%
#you are having duplicate and you want to delete it.
df1=df1.drop_duplicates()
df1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#missing values:

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df1.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df1["Self_Employed"].mode()
# Out:
# 0    No
# Name: Self_Employed, dtype: object

# %%
#df1["Self_Employed"]=df1["Self_Employed"].fillna("No")
df1["Self_Employed"]=df1["Self_Employed"].fillna(df1["Self_Employed"].mode()[0])

# %%
df1.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df1["Self_Employed"].mode()
# Out:
# 0    No
# Name: Self_Employed, dtype: object

# %%
df1["Credit_History"].describe()
# Out:
# count    564.000000
# mean       0.842199
# std        0.364878
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: Credit_History, dtype: float64

# %%
x=df1["Credit_History"].astype("object")

# %%
x.mode()
# Out:
# 0    1.0
# Name: Credit_History, dtype: object

# %%
df1["LoanAmount"].describe()
# Out:
# count    614.000000
# mean     145.752443
# std       84.107233
# min        9.000000
# 25%      100.250000
# 50%      128.000000
# 75%      164.750000
# max      700.000000
# Name: LoanAmount, dtype: float64

# %%
df1["LoanAmount"].median()
# Out:
# 128.0

# %%
df1["LoanAmount"]=df1["LoanAmount"].fillna(df1["LoanAmount"].median())

# %% [markdown]
# # Feature Engineering:

# %%
df1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#total income

df1["total_income"]=df1["ApplicantIncome"]+df1["CoapplicantIncome"]

# %%
df1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...
